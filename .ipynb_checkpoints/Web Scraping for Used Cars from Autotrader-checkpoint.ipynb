# %% [markdown]
# # Web Scraping for Used Car Prices from Autotrader.ca

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required modules
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import requests
import re
import pymongo
import pandas as pd
from sqlalchemy import create_engine,inspect, func
import numpy as np
import time
#from config import api_key

# %%
# This is to initialize Splinter for Windows users
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# list to store extracted values

title_list=[]
year_list=[]
price_list=[]
loc_list=[]
date_list=[]
milage_list=[]
car_list=[]
model_list=[]
trans_list=[]

# loop to scrap website

url = "https://www.autotrader.ca/cars/?rcp=15&rcs=0&srt=9&prx=-1&hprc=True&wcp=True&sts=New-Used&inMarket=advancedSearch"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
results = soup.find_all('div', class_='newSRPDesign')


i=1

while i<=2:
  
    for result in results:
       
        
        try:
            
            # scrape the price
            price = result.find('span', class_='price-amount').text
            price_list.append(price)
            # scrape the  Title
            ctitle = result.find('div', class_='listing-details').h2.a.span.text
            #words=['lease', 'take over', 'finance', 'financing', 'leasing', 'takeover', 'financed', 'leased', 'transfer', 'transferring']
            #for word in words:
            
                #if word in result.find('div', class_='title').text.split():
                    #print('a listing including lease or finance was removed')
                #elif word in result.find('div', class_='description').text.split():
                    #print('a listing including lease or finance was removed')
                #else:
            btitle= ctitle.split('\n')[1].replace('                                    ','')
            title = btitle.split('                                    ')[0]
            year = title.split(" ")[0]
            cartype= title.split(" ")[1]
            model = title.split(" ")[2]
            title_list.append(title)
            year_list.append(year)
            car_list.append(cartype)
            model_list.append(model)
         
            
            
        # scrape the  Location
            #location = result.find('div', class_='location').text.split()[0]
            #loc_list.append(location)
        
         
        
        
        
        # scrape the  Date
            #date = result.find('span', class_='date-posted').text
            #date_list.append(date)
        # scrape the  details
            details = result.find('div', class_='kms').text#.split('"')[0]         
            milage=details
           
            
            milage_list.append(milage)            
   
    
        except AttributeError:
            date=''
        except IndexError:
            cartype=''
            model=''
    
    browser.find_link_by_text(1+i).first.click()
    i=i+1    
# store the extracted valuse in dictionary            
Dict={}
Dict["Title"]=title_list
Dict["Car Type"]=car_list
Dict["Model"]=model_list
Dict["Price"]=price_list
#Dict["Location"]=loc_list
#Dict["Date"]=date_list
Dict["Milage"]=milage_list
Dict["Year"]=year_list
#Dict["Transmission"]=trans_list

# %%
df=pd.DataFrame.from_dict(Dict, orient='index')
df=df.transpose()
df
# Out:
#                                                 Title    Car Type    Model  \
# 0                         2020 Nissan Murano PLATINUM      Nissan   Murano
# 1   2017 Lexus RX 350 Executive Pkg- Panoramic Roo...       Lexus       RX
# 2   2011 BMW 328 X-DRIVE 6 VITESSE MANUEL CUIR TOI...         BMW      328
# 3   2015 Mazda Mazda3 GS W/SUNROOF, LOW KMS, AUTO,...       Mazda   Mazda3
# 4                   2019 Volkswagen Atlas COMFORTLINE  Volkswagen    Atlas
# 5   2019 Toyota Corolla XSE: Sunroof/ Navigation/ ...      Toyota  Corolla
# 6                            2011 Audi A3 TDI Premium        Audi       A3
# 7                                  2019 BMW i8 Coupe          BMW       i8
# 8   2019 Dodge Grand Caravan CANADA VALUE PKG*REAR...       Dodge    Grand
# 2017 Hyundai Sonata **GL**NO ACCIDENT**LOW KM**ONE OWNER**REAR CAMERA*    2
#                                                                          ..
# 2016 Chrysler 200 Limited,$105b/w,Heated seats/Steering Wheel,Remote      2
# 2020 Lincoln Corsair Ultra                                                2
# 2019 Mazda CX-3 GS Auto AWD                                               2
# 2016 Subaru Forester Touring PanaRoof Htd Seat Backcam Pwr Liftgate       2
# 2015 Ram 3500 LARAMIE BLACK APPEARANCE CREW CAB DIESEL                    2
# 2018 Jeep Grand Cherokee Limited 4x4                                      2
# 1993 Land Rover Defender 110                                              2
# 2015 Ram 3500 LARAMIE CREW CAB SWB 4WD 6.7L LARAMIE                       2
# 2016 Ford F-150 4WD SuperCrew 157  Lariat                                 2
# 2011 Toyota Tundra 4WD Double Cab 165 5.7L SR5                            2
# 2015 Hyundai Veloster 3dr Cpe Auto Turbo                                  2
# 2017 Honda CR-V AWD 5dr LX                                                2
# 2019 Jaguar F-Pace 25t R-Sport AWD PANO ROOF / NAVIGATION / REAR CAM      2
# 2014 Hyundai Elantra 4dr Sdn Auto Limited w/Navi                          2
# 2005 Kia Sportage 4dr EX 4WD V6 Auto                                      2
# 2009 Volkswagen City Jetta 4dr Sdn Man                                    2
# 2019 Jeep Wrangler UNLIMITED JL 4X4 CUSTOM WHEEL PKG ONLY 22K             2
# 1969 Chevrolet Camaro SS                                                  2
# 2017 Lexus RX 350 AWD 4dr                                                 2
# 2011 Toyota Camry 4dr Sdn I4 Auto LE                                      2
# 2011 Acura MDX AWD 4dr                                                    2
# 2017 Kia Sorento EX V6 AWD + 7 PLACES + GARANTIE + MAGS +                 2
# 2020 Mercedes-Benz GLC300 4MATIC SUV                                      2
# 2007 Toyota Sienna 5dr XLE Mobility 8-Passenger 2WD                       2
# 2020 Ram 1500 Longhorn                                                    2
# 2016 Ford Expedition PLATINUM 4WD DVD MOON LOADED 2ND ROW CAPTAINS        2
# 2016 BMW 4-Series 435i xDrive                                             2
# 1974 Chevrolet Nova                                                       2
# 2014 Jeep Wrangler 4WD 2dr Sport                                          2
# 2011 Dodge RAM 3500 PICKUP Slt                                            2
# Name: Title, Length: 111, dtype: int64

# %%
df["Price"] = df["Price"].str.replace("$", "")
df["Price"] = df["Price"].str.replace(",", "")
df["Milage"] = df["Milage"].str.replace(",", "")
df["Milage"] = df["Milage"].str.replace("\nMileage", "")
df["Milage"] = df["Milage"].str.replace("\n", "")
df["Milage"] = df["Milage"].str.replace("km", "")

# %%
df.reset_index()
df.dropna()
df.drop_duplicates()
df = df.mask(df.eq('None')).dropna()

# %%
df

# %%
df['Milage'].value_count()

# %%
from config import password
connection_string = "postgres:"+password+"@localhost:5432/hondadb"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
#engine.table_names()
inspector = inspect(engine)
inspector.get_table_names()

# %%
inspector.get_columns("cardb")

# %%
df.to_sql(name='cardb', con=engine, if_exists='replace', index=True)

# %%
sql_DF = pd.read_sql("SELECT * FROM cardb",
                     con=engine)

# %%
sql_DF.info()
