# %% [markdown]
# # Web Scraping for Used Car Prices from Autotrader.ca

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required modules
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import requests
import re
import pymongo
import pandas as pd
from sqlalchemy import create_engine,inspect, func
import numpy as np
import time
import sqlite3
#from config import api_key

# %%
# This is to initialize Splinter for Windows users
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# list to store extracted values

title_list=[]
year_list=[]
price_list=[]
loc_list=[]
date_list=[]
milage_list=[]
car_list=[]
model_list=[]
trans_list=[]

# loop to scrap website
#scraping 600 pages with 100 listings per pge
for item_num in range(0, 60001, 100):
    url = "https://www.autotrader.ca/cars/?rcp=100&rcs="+str(item_num)+"&srt=9&prx=-1&hprc=True&wcp=True&sts=New-Used&inMarket=advancedSearch"
    browser.visit(url)
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    results = soup.find_all('div', class_='newSRPDesign')


    for result in results:
               
        try:
                
            # scrape the price
            price = result.find('span', class_='price-amount').text
            price_list.append(price)
            # scrape the  Title
            ctitle = result.find('div', class_='listing-details').h2.a.span.text
            
                
            btitle= ctitle.split('\n')[1].replace('                                    ','')
            title = btitle.split('                                    ')[0]
            year = title.split(" ")[0]
            cartype= title.split(" ")[1]
            model = title.split(" ")[2]
            title_list.append(title)
            year_list.append(year)
            car_list.append(cartype)
            model_list.append(model)
         
            
            
        # scrape the  Location
            location = result.find('span', class_='proximity-text').text.split()[1]
            loc_list.append(location)
            
            
            
            
            
        #scrape the milage
            details = result.find('div', class_='kms').text#.split('"')[0]         
            milage=details
            milage_list.append(milage)            
   
    
        except AttributeError:
            date=''
        except IndexError:
            cartype=''
            model=''
            
#browser.find_link_by_text(i+1).first.click()
#i=i+1


# store the extracted valuse in dictionary            
Dict={}
Dict["Title"]=title_list
Dict["Car Type"]=car_list
Dict["Model"]=model_list
Dict["Price"]=price_list
Dict["Location"]=loc_list
#Dict["Date"]=date_list
Dict["Milage"]=milage_list
Dict["Year"]=year_list
#Dict["Transmission"]=trans_list

# %%
df=pd.DataFrame.from_dict(Dict, orient='index')
df=df.transpose()
ndf=df.drop_duplicates(['Title', 'Price', 'Year'])
ndf
# Out:
#                                                    Title       Car Type  \
# 0                                       2018 Ford F-150            Ford
# 1                         2017 Mercedes-Benz GLS GLS 450  Mercedes-Benz
# 2      2016 Dodge Journey AWD 4dr R-T / Leather / Blu...          Dodge
# 3         2017 Ford Edge SPORT, TOIT PANO, CUIR, GPS/NAV           Ford
# 4      2019 Nissan Versa Note SV - just like new, ver...         Nissan
# 5      2016 Volkswagen Golf R GOLF - TECHNOLOGY PACKA...     Volkswagen
# 6      2014 Jeep Grand Cherokee Overland *LOCALLY DRI...           Jeep
# 7                           2015 GMC Acadia FWD 4dr SLE1            GMC
# 8      2019 Ram 1500 Classic Express Night | 4x4 | Cr...            Ram
# 9                              2020 Jeep Compass Limited           Jeep
# 10       2015 Nissan Micra NO PAYMENTS FOR 3 MONTHS! !!!         Nissan
# 11     2017 Volkswagen Golf 5dr HB Auto 1.8 TSI Trend...     Volkswagen
# 12     2019 Jeep Grand Cherokee Limited AWD, Navi, Su...           Jeep
# 13                               2017 Chevrolet Cruze LT      Chevrolet
# 14     2019 Jeep Grand Cherokee Limited AWD, Navi, Su...           Jeep
# 15                     2015 Toyota Corolla 4dr Sdn CVT S         Toyota
# 16     2019 Jeep Grand Cherokee Limited 4x4, Navi, Su...           Jeep
# 17                   2018 Mazda Mazda3 GX A/C BLUETOOTH           Mazda
# 6          Grand  $25,688    St-Esprit,
# 7         Acadia  $16,998       Guelph,
# 8           1500  $42,390  Bridgewater,
# 9        Compass  $40,665      Toronto,
# 10         Micra  $10,777        Grande
# 11          Golf  $18,888      Sherwood
# 12         Grand  $38,995      Candiac,
# 13         Cruze  $14,998      Candiac,
# 14         Grand  $38,795      Candiac,
# 15       Corolla  $12,950      Candiac,
# 16         Grand  $38,895      Candiac,
# 17        Mazda3  $13,999      Candiac,
# 18         Camry  $28,609      Moncton,
# 19          370Z  $33,500      Moncton,
# 20             5  $27,500      Moncton,
# 21       Corolla   $3,700      Moncton,
# 22        Escape   $5,800      Moncton,
# 23       Journey   $9,500      Moncton,
# 24        Escape   $5,500      Moncton,
# 25           XT5  $31,995      Moncton,
# 26         Grand  $15,995          Port
# 27        Tucson  $33,729       Surrey,
# 29          1500  $36,975       Surrey,
# 30         Grand  $12,797       Surrey,
# ...          ...      ...           ...
# 67281      Cruze  $10,794          None
# 67282     Sentra   $6,994          None
# 67283      Civic  $19,382          None
# 67284       CR-V  $19,728          None
# 67285       CR-V  $19,738          None
# 67286      Civic  $14,994          None
# 67287      Civic  $15,457          None
# 67288      Civic  $10,368          None
# 67289      Civic  $16,324          None
# 67290      Rogue  $17,777          None
# 67291    Elantra  $15,666          None
# 67292       CR-V  $22,888          None
# 67293      Rogue  $18,500          None
# 67294    Sorento   $9,994          None
# 67295      Civic   $1,497          None
# 67296     Legacy  $19,995          None
# 67297  Crosstrek  $20,995          None
# 67298   Corvette  $55,000          None
# 67299        Ram   $2,495          None
# 67301     Accent   $1,500          None
# 67302     Sienna  $22,994          None
# 67303        200  $14,948          None
# 67304    Compass  $33,380          None
# 67305    Compass  $38,275          None
# 67306       1500  $67,380          None
# 67307       1500  $52,245          None
# 67308  ProMaster  $24,948          None
# 67309       CX-3  $15,657          None
# 67310     Accent   $9,877          None
# 67311       CX-9  $25,777          None
#
#                                                   Milage  Year
# 0      \nMileage 64,965 km\n                         ...  2018
# 1      \nMileage 57,449 km\n                         ...  2017
# 2      \nMileage 28,567 km\n                         ...  2016
# 3      \nMileage 63,500 km\n                         ...  2017
# 4      \nMileage 87,760 km\n                         ...  2019
# 5      \nMileage 419 km\n                            ...  2016
# 6      \nMileage 237,366 km\n                        ...  2014
# 7      \nMileage 42,420 km\n                         ...  2015
# 8      \nMileage 27,766 km\n                         ...  2019
# 9      \nMileage 120,750 km\n                        ...  2020
# 10     \nMileage 21,432 km\n                         ...  2015
# 11     \nMileage 67,252 km\n                         ...  2017
# 12     \nMileage 136,000 km\n                        ...  2019
# 13     \nMileage 132,000 km\n                        ...  2017
# 14     \nMileage 108,042 km\n                        ...  2019
# 15     \nMileage 79,344 km\n                         ...  2015
# 16     \nMileage 109,200 km\n                        ...  2019
# 17     \nMileage 228,816 km\n                        ...  2018
# 18     \nMileage 28,848 km\n                         ...  2018
# 19     \nMileage 10,334 km\n                         ...  2017
# 20     \nMileage 36,300 km\n                         ...  2016
# 21     \nMileage 28,500 km\n                         ...  2007
# 22     \nMileage 315,550 km\n                        ...  2008
# 23     \nMileage 68,479 km\n                         ...  2012
# 24     \nMileage 90,751 km\n                         ...  2008
# 25     \nMileage 60,365 km\n                         ...  2017
# 26     \nMileage 69,054 km\n                         ...  2012
# 27     \nMileage 74,358 km\n                         ...  2020
# 29     \nMileage 39,767 km\n                         ...  2017
# 30     \nMileage 230,000 km\n                        ...  2014
# ...                                                  ...   ...
# 67281                                               None  2016
# 67282                                               None  2014
# 67283                                               None  2018
# 67284                                               None  2016
# 67285                                               None  2016
# 67286                                               None  2016
# 67287                                               None  2016
# 67288                                               None  2015
# 67289                                               None  2017
# 67290                                               None  2016
# 67291                                               None  2018
# 67292                                               None  2017
# 67293                                               None  2017
# 67294                                               None  2013
# 67295                                               None  2005
# 67296                                               None  2016
# 67297                                               None  2017
# 67298                                               None  2014
# 67299                                               None  2004
# 67301                                               None  2003
# 67302                                               None  2015
# 67303                                               None  2015
# 67304                                               None  2020
# 67305                                               None  2020
# 67306                                               None  2020
# 67307                                               None  2020
# 67308                                               None  2019
# 67309                                               None  2017
# 67310                                               None  2016
# 67311                                               None  2017
#
# [57817 rows x 7 columns]

# %%
ndf["Milage"] = ndf["Milage"].str.replace("\nMileage", "")
ndf["Milage"] = ndf["Milage"].str.replace("\n", "")
ndf["Milage"] = ndf["Milage"].str.replace("km", "")
ndf["Milage"] = ndf["Milage"].str.replace('                                 ', "")
ndf["Milage"] = ndf["Milage"].str.replace(' ', "")
ndf["Milage"] = ndf["Milage"].str.replace(",", "")
ndf["Price"] = ndf["Price"].str.replace("$", "")
ndf["Price"] = ndf["Price"].str.replace(",", "")
ndf["Location"] = ndf["Location"].str.replace(",", "")

# %%
ndf.reset_index()
ndf.dropna()
ndf.drop_duplicates()
ndf = ndf.mask(ndf.eq('None')).dropna()

# %%
ndf
# Out:
#                                                    Title       Car Type  \
# 0                                       2018 Ford F-150            Ford
# 1                         2017 Mercedes-Benz GLS GLS 450  Mercedes-Benz
# 2      2016 Dodge Journey AWD 4dr R-T / Leather / Blu...          Dodge
# 3         2017 Ford Edge SPORT, TOIT PANO, CUIR, GPS/NAV           Ford
# 4      2019 Nissan Versa Note SV - just like new, ver...         Nissan
# 5      2016 Volkswagen Golf R GOLF - TECHNOLOGY PACKA...     Volkswagen
# 6      2014 Jeep Grand Cherokee Overland *LOCALLY DRI...           Jeep
# 7                           2015 GMC Acadia FWD 4dr SLE1            GMC
# 8      2019 Ram 1500 Classic Express Night | 4x4 | Cr...            Ram
# 9                              2020 Jeep Compass Limited           Jeep
# 10       2015 Nissan Micra NO PAYMENTS FOR 3 MONTHS! !!!         Nissan
# 11     2017 Volkswagen Golf 5dr HB Auto 1.8 TSI Trend...     Volkswagen
# 12     2019 Jeep Grand Cherokee Limited AWD, Navi, Su...           Jeep
# 13                               2017 Chevrolet Cruze LT      Chevrolet
# 14     2019 Jeep Grand Cherokee Limited AWD, Navi, Su...           Jeep
# 15                     2015 Toyota Corolla 4dr Sdn CVT S         Toyota
# 16     2019 Jeep Grand Cherokee Limited 4x4, Navi, Su...           Jeep
# 17                   2018 Mazda Mazda3 GX A/C BLUETOOTH           Mazda
# 18                             2018 Toyota Camry XSE V6          Toyota
# 19                                     2017 Nissan 370Z          Nissan
# 20                                    2016 BMW 5 Series             BMW
# 21                   2007 Toyota Corolla 4dr Sdn Auto CE         Toyota
# 22                       2008 Ford Escape 4WD 4dr V6 XLT           Ford
# 23                        2012 Dodge Journey AWD 4dr R/T          Dodge
# 24                       2008 Ford Escape 4WD 4dr V6 XLT           Ford
# 19            370Z  33500      Moncton   10334  2017
# 20               5  27500      Moncton   36300  2016
# 21         Corolla   3700      Moncton   28500  2007
# 22          Escape   5800      Moncton  315550  2008
# 23         Journey   9500      Moncton   68479  2012
# 24          Escape   5500      Moncton   90751  2008
# 25             XT5  31995      Moncton   60365  2017
# 26           Grand  15995         Port   69054  2012
# 27          Tucson  33729       Surrey   74358  2020
# 29            1500  36975       Surrey   39767  2017
# 30           Grand  12797       Surrey  230000  2014
# ...            ...    ...          ...     ...   ...
# 46588      Elantra  29009       Ottawa   75194  2020
# 46590        Venue  26909       Ottawa   58900  2020
# 46592  Convertible  22995       Ottawa  121975  2017
# 46593        Rover  75524     Edmonton   17195  2018
# 46594       Sedona  15497     Edmonton  119471  2016
# 46595           A4  28625     Edmonton   52400  2018
# 46598     Forester  20950     Rosetown   89071  2016
# 46599      Qashqai  21798       Prince  152000  2018
# 46600       Sonata   9992       Exeter  163142  2013
# 46601    CLA-Class  23995   Sherbrooke   33085  2015
# 46602        Jetta   9999       Vernon   60670  2012
# 46603         1500  50151  Orangeville   68657  2019
# 46604         Kona  26609      Toronto   80785  2020
# 46607         Kona  29559       Vernon   84500  2020
# 46608        F-150  78449       Vernon  100567  2019
# 46611        Grand  57880       Vernon   72441  2020
# 46615         1500  56300       Delson   36325  2020
# 46616        Grand  57605       Delson   22365  2020
# 46617       Sierra  64848       Delson   23729  2020
# 46618       Sierra  41507       Delson   33007  2020
# 46619    SILVERADO  61132       Ottawa   48475  2020
# 46620      Equinox  35353       Ottawa  147205  2020
# 46623     Colorado  36809    Woodstock   38000  2020
# 46624       Malibu  30273     Richmond   35000  2020
# 46625       Blazer  55573      Calgary  222417  2020
# 46626     Colorado  59563    Vancouver   66078  2020
# 46627      Equinox  41697    Vancouver   99135  2020
# 46628       SIERRA  89712      Toronto   70855  2020
# 46629      Equinox  41297    Etobicoke   73745  2020
# 46633        Pilot  56031     Kingston   92948  2020
#
# [40993 rows x 7 columns]

# %%
from config import password
connection_string = "postgres:"+password+"@localhost:5432/hondadb"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
#engine.table_names()
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['cleanedhondadb2', 'cleanedcardb', 'cleanedcardb2', 'cardb', 'hondadb']

# %%
inspector.get_columns("cardb")
# Out:
# [{'name': 'index',
#   'type': BIGINT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Title',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Car Type',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Model',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Price',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Location',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Milage',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Year',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %%
ndf.to_sql(name='cardb', con=engine, if_exists='replace', index=True)

# %%
sql_DF = pd.read_sql("SELECT * FROM cardb",
                     con=engine)

# %%
sql_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40993 entries, 0 to 40992
# Data columns (total 8 columns):
# index       40993 non-null int64
# Title       40993 non-null object
# Car Type    40993 non-null object
# Model       40993 non-null object
# Price       40993 non-null object
# Location    40993 non-null object
# Milage      40993 non-null object
# Year        40993 non-null object
# dtypes: int64(1), object(7)
# memory usage: 2.5+ MB

# %%
conn = sqlite3.connect('car.sqlite')
ndf.to_sql('carsdb', conn, if_exists='replace', index=False)

# %%
sql_DF2=pd.read_sql('select * from carsdb', conn)

# %%
sql_DF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40993 entries, 0 to 40992
# Data columns (total 7 columns):
# Title       40993 non-null object
# Car Type    40993 non-null object
# Model       40993 non-null object
# Price       40993 non-null object
# Location    40993 non-null object
# Milage      40993 non-null object
# Year        40993 non-null object
# dtypes: object(7)
# memory usage: 2.2+ MB
